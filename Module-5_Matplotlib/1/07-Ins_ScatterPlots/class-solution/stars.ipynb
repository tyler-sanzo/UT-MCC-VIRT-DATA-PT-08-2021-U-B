# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Out:
# array(['orange', 'green', 'green', 'orange', 'green', 'blue', 'blue',
#        'red', 'green', 'red', 'orange', 'purple', 'purple', 'red',
#        'purple', 'red', 'blue', 'blue', 'orange', 'green', 'purple',
#        'purple', 'green', 'blue', 'red', 'purple', 'green', 'red',
#        'purple', 'blue', 'blue', 'blue', 'purple', 'purple', 'orange',
#        'green', 'purple', 'purple', 'purple', 'red', 'orange', 'red',
#        'red', 'orange', 'orange', 'orange', 'orange', 'red', 'orange',
#        'purple', 'red', 'green', 'orange', 'red', 'green', 'orange',
#        'green', 'purple', 'blue', 'blue', 'red', 'red', 'green', 'blue',
#        'blue', 'blue', 'orange', 'blue', 'purple', 'orange', 'purple',
#        'green', 'purple', 'purple', 'red', 'purple', 'blue', 'purple',
#        'blue', 'red', 'green', 'orange', 'orange', 'green', 'red',
#        'orange', 'red', 'purple', 'purple', 'orange', 'green', 'blue',
#        'purple', 'blue', 'purple', 'blue', 'red', 'green', 'orange',
#        'purple'], dtype='<U6')

# %%
x = np.random.randint(0, 100, 100)
y = np.random.randint(0, 100, 100)
z = np.random.randint(0, 100, 100)
w = np.random.choice(["red", "green", "blue", "purple", "orange"], 100)

# %%
z
# Out:
# array([ 0, 39, 66, 20, 43, 48, 15, 94, 57, 32, 37, 39, 63,  9, 32, 30, 17,
#        12, 28, 42, 72, 61,  1, 17, 50, 48, 20, 93, 22, 17,  5, 77, 78, 28,
#         6,  2, 30, 66, 84, 87, 63, 77, 39, 25, 35, 83, 44, 61, 59, 22, 82,
#         9, 65, 95, 92, 66, 72, 62,  2, 89, 82, 44, 76, 64, 77, 11, 41, 31,
#        97, 24, 75, 50, 70, 60, 15, 34, 39, 96, 49, 21, 66, 84, 71,  6, 38,
#         2,  3, 31, 21, 85, 96, 50, 66,  8, 79,  1, 46, 26, 89, 45])

# %%
plt.scatter(x, y, s=z, marker="*", facecolors=w, edgecolors="black", alpha=.50)
